# %%
#Loading dependencies 
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re
# %matplotlib inline

# %%
from pyvi import ViTokenizer, ViPosTagger
def remove_pattern(row_content):
    return re.sub(r'[?|$|.|!]',r'', row_content)
def tokenize(row_content):
    return ViTokenizer.tokenize(row_content)

# %%
reviews = pd.read_csv("train.txt", sep='\t')
reviews['Content'] = reviews['Content'].apply(remove_pattern)
reviews['Content'] = reviews['Content'].apply(process_review)
reviews.head()
# Out:
#   ID Sentiment Content
# 0  0         1      []
# 1  1         1      []
# 2  2         1      []
# 3  3         0      []
# 4  4         1      []

# %%
# visualizing data
review_words = ' '.join(list(reviews[reviews['Sentiment']=='1']['Content']))
review_wc = WordCloud(width=512, height=512).generate(review_words)
plt.figure(figsize = (10,8), facecolor='k')
plt.imshow(review_wc)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
review_words = ' '.join(list(reviews[reviews['Sentiment']=='0']['Content']))
review_wc = WordCloud(width=512, height=512).generate(review_words)
plt.figure(figsize = (10,8), facecolor='k')
plt.imshow(review_wc)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~/.conda/envs/jupyter/lib/python3.7/site-packages/nltk/corpus/util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~/.conda/envs/jupyter/lib/python3.7/site-packages/nltk/data.py in find(resource_name, paths)
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/home/hocx3/nltk_data'
# ...

# %%
from nltk.tokenize import word_tokenize
def process_review(review, lower_case=True, stop_words=True, gram=2):
    if lower_case:
        review = review.lower()
    tokenized_review = tokenize(review)
    words = word_tokenize(tokenized_review)
    
#     words = [w for w in words if len(w) > 2]
    print(words)
    
    
#     w = []
#     for i in range(len(words) - 1):
#         w += [' '.join(words[i:i + 2])]
# #     sw = set(['thì', 'là', 'mà', 'cả', 'cái', 'chứ', 'đang', 'cứ'])
# #     words = [word for word in words if word not in sw]
#     return w
# #     return words

# %%
process_review("abc xyz")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-30-bbbcc24c66fd> in <module>
# ----> 1 process_review("abc xyz")
#
# <ipython-input-29-a7e1ca276190> in process_review(review, lower_case, stop_words, gram)
#       3     if lower_case:
#       4         review = review.lower()
# ----> 5     words = word_tokenize(review)
#       6 #     words = [w for w in words if len(w) > 2]
#       7     print(words)
#
# ~/.conda/envs/jupyter/lib/python3.7/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     141     :type preserve_line: bool
#     142     """
# --> 143     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     144     return [
#     145         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# ...

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-3b02390c7677> in <module>
#       1 import nltk
# ----> 2 nltk.download()
#
# ~/.conda/envs/jupyter/lib/python3.7/site-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     771             if download_dir is not None:
#     772                 self._download_dir = download_dir
# --> 773             self._interactive_download()
#     774             return True
#     775
#
# ~/.conda/envs/jupyter/lib/python3.7/site-packages/nltk/downloader.py in _interactive_download(self)
#    1121         if TKINTER:
#    1122             try:
# -> 1123                 DownloaderGUI(self).mainloop()
#    1124             except TclError:
# ...
